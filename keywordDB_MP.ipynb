# %% [markdown]
# # Dummy Data Generator for Keyword Simulation using Mimesis Plugin

# %% [markdown]
# Recently, we create a MySQL DB that helps store complex & loads of Keyword Results from marketplace, and SEOs.  Currently, we managed to set up the keyword marketplace tables which we call them platoform_a and platform_b, where our main goal is to create Loads of Dummy Data rows that seems like legit data as SIMULATION purposes.

# %% [markdown]
# <p style="color: red; margin-bottom: -1%;"><b>Please Take Note:</b></p>
# <p style="color: red;">Never use this dummy data generator as frauds or other worse case scenarios, thankyou for your understanding.</p>

# %% [markdown]
# ## #1: Initiate Python

# %% [markdown]
# Before starting our Dummy Data Generator, please run these code as below:

# %%
# pip install pandas
# pip install numpy
import pandas as pd
import numpy as np

# %%
import os
os.getcwd()
# Out:
# 'd:\\4 - Masterclass Collections (udemy, seminar, dkk)\\34_dataFaking_plugins_github\\2_mimesis\\mimesis_experiment'

# %% [markdown]
# After initiate, you may proceed to the next step.

# %% [markdown]
# ## #2: Dummy Data Generating

# %% [markdown]
# In this part, we'll show you how you can generate a complex rows of dummy data for your Database Portfolios and Simulations.  In every part, we'll always write 'import os from Mimesis' before proceed writing the 'generic' part.

# %% [markdown]
# <div>
#     <h3>And by the way what is 'Mimesis'?</h3>
#     <p>Mimesis is a plugin from Github, acts as a robust data generator for Python that can produce a wide range of dummy data in "various languages".</p>
#     <p>Famously, most developer loves to use 'faker' as their plugin to generate dummy data, but faker concentrate more to math problems, different than mimesis. CMIIW.</p>
#     <div>
#         <p>Let'me give reference link towards each of this plugin:</p>
#         <ol>
#             <li>Mimesis Plugin: <a href="https://github.com/lk-geimfari/mimesis">https://github.com/lk-geimfari/mimesis</a></li>
#             <li>Faker Plugin: <a href="https://github.com/joke2k/faker">https://github.com/joke2k/faker</a></li>
#         </ol>
#     </div>
#     <p>We hope it helps for your portfolio.  Below here, is our detailed example of one of our dummy generator for our MySQL Database Simulation.</p>
# </div>

# %% [markdown]
# ### 1 - Kelompok Profil

# %% [markdown]
# #### 1.1. Table Profile

# %% [markdown]
# This table profile is to store lists of e-commerce or marketplace randomly, before initiating fake reports generation.  Please feel free to use if you want to generate marketplace or e-commerce lists as your portfolio.

# %%
import csv
import os
from mimesis import Generic
from mimesis.locales import Locale

g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('csv_forSQLTable/1_profile/1_profile_table.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    profile_category = [['jenisMP'],['tokosidia'],['sope'],['amazing'],['alimama']]    
    
    # Write each row individually
    for row in profile_category:
        writer.writerow(row)

print(os.getcwd())
print("✅ CSV file '1_profile_table.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '1_profile_table.csv' has been created successfully!

# %% [markdown]
# #### 1.2. Table Nama Toko MP

# %% [markdown]
# This section is use to Generate Store Name, adding with its ID when necessary.

# %%
import csv
import os
from mimesis import Generic
from mimesis.locales import Locale

g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('csv_forSQLTable/1_profile/2_namaTokoMarketplace.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    #writer.writerow('namaToko','idToko')
    #profile_category = np.array(['tokosidia', 'sope', 'alimama', 'amazing'])
    namaTokoMarketplace = [['namaToko','idToko'],['dodolan store','1552341523'],['palugada store','5343412870']]    
    
    # Write each row individually
    for row in namaTokoMarketplace:
        writer.writerow(row)
    #writer.writerow(profile_category)

print(os.getcwd())
print("✅ CSV file '2_namaTokoMarketplace.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '2_namaTokoMarketplace.csv' has been created successfully!

# %% [markdown]
# ### 2 - Kelopok Laporan

# %% [markdown]
# #### Date Generator

# %% [markdown]
# Generate Fake Datetime for rows of Databases with Datetime data types.  Feel free to to use this DateTime, adjust its 'K random number' as needed on 'random_dates = generate_random_dates(start_date, end_date, k)'.  For instance there's 10 rows with empty DateTime (for experiment and portfolio purposes), change k to '10' before generating to CSV file.

# %%
import csv
import os
import datetime
import random
from datetime import timedelta, datetime
from mimesis import Generic
from mimesis.locales import Locale

g = Generic(locale=Locale.EN)

def generate_random_dates(start_date, end_date, k):
    random_dates = []
    
    date_range = end_date - start_date
    for _ in range(k):
        random_days = random.randint(0, date_range.days)
        random_date = start_date + timedelta(days=random_days)
        random_dates.append(random_date)
    return random_dates

start_date = datetime(2024, 1, 1)
end_date = datetime(2025, 1, 1)
random_dates = generate_random_dates(start_date, end_date, 5)
#print("The random dates generated are:")
for index, date in enumerate(random_dates):
    #print(f"{index+1}. {date.strftime('%Y-%m-%d')}") 
    print(f"{date.strftime('%Y-%m-%d')}") 

# Open a CSV file for writing
with open('csv_forSQLTable/2_laporan/1_laporan.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    # tuliskan header sebagai list
    writer.writerow(['waktuLaporanDibuat'])

    # Format setiap tanggal ke string dan tuliskan sebagai baris terpisah
    for date in random_dates:
        writer.writerow([date.strftime('%Y-%m-%d')])
    # Jadi bukan waktu_laporan_dibuat = ([random_dates])

    # Write each row individually
    #for row in waktu_laporan_dibuat:
        #writer.writerow(row)
    #writer.writerow(waktu_laporan_dibuat)

print(os.getcwd())
print("✅ CSV file '1_laporan.csv' has been created successfully!")

#Reference: https://www.tutorialspoint.com/how-to-generate-k-random-dates-between-two-other-dates-using-python
# Out:
# 2024-06-17
# 2024-05-19
# 2024-11-19
# 2024-08-26
# 2024-10-12
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '1_laporan.csv' has been created successfully!

# %% [markdown]
# ### 3 - Kelompok Iklan Platform A

# %% [markdown]
# Sekumpulan Tabel dari Hasil Laporan Iklan Platform A

# %% [markdown]
# #### 3.1. Hasil Laporan Iklan Platform A

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('csv_forSQLTable/platform_a/1_hasil_laporan_iklan_platform_a.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    #writer.writerow(['No', 'Product Group', 'Product Name', 'Product Keyword', 'Income', 'Outcome', 'Ads Effectiveness in Total', 'Ads Effectiveness', 'Performance', 'Show on Top Page', 'View', 'Click', 'Click Percentage', 'Sold', 'Total Sold', 'Percentage Sold', 'Average'])
    writer.writerow(['namaGrup', 'namaProduk', 'pengeluaran', 'pendapatan', 'totalEfektivitasIklan', 'efektivitasIklan', 'performaTampil', 'tampilTeratas', 'tampil', 'klik', 'persentaseKlik', 'terjual', 'totTerjual', 'persentaseTerjual', 'rataRata'])

    for i in range(1, 120):
        # To Generate Random Strings
        # 1. Product Group
        # 2. Product Name
        # 3. Keywords
        product_category = ['dish', 'drink', 'fruit', 'spices', 'vegetable']
        product_category = g.random.choice(product_category)

        if product_category == 'dish':
            product_name = g.food.dish()
            dish_random = [f'Delicious {product_name}', f'Home made {product_name} dishes', f'{product_name} that makes Hungry']
            product_keyword = g.random.choice(dish_random)
        elif product_category == 'drink':
            product_name = g.food.drink()
            drink_random = [f'{product_name} for rehydration', f'Fresh and Cold {product_name}', f'Refreshingly {product_name} drink']
            product_keyword = g.random.choice(drink_random)
        elif product_category == 'fruit':
            product_name = g.food.fruit()
            fruit_random = [f'{product_name} moodbooster', f'Colorful and healthy {product_name}', f'{product_name} that refreshes your mind']
            product_keyword = g.random.choice(fruit_random)
        elif product_category == 'spices':
            product_name = g.food.spices()
            spices_random = [f'Colourful {product_name} spice', f'{product_name} flavoring', f'Family Recommend {product_name}', f'Hot and Spicy {product_name}']
            product_keyword = g.random.choice(spices_random)
        elif product_category == 'vegetable':
            product_name = g.food.vegetable()
            vegetable_random = [f'Healthy {product_name} vegetables', f'{product_name} perfect for vegetarians', f'Fully Green {product_name}']
            product_keyword = g.random.choice(vegetable_random)

        # To Generate The Statistics Random Number (for Int and Float)
        class MyRandomNumber(BaseProvider):
            class Meta:
                name = 'randomNumber'
            
            # 4. Random Outcome $
            def random_outcome(self):
                return self.random.randint(0, 20000)

            # 5. Random Income $
            def random_income(self):
                return self.random.randint(30000, 500000)

            # 9. Show on Top Page
            def random_topPage(self):
                return self.random.randint(0, 300)

            # 10. Views
            def random_view(self):
                return self.random.randint(0, 700)
            
            # 11. Click
            def random_click(self):
                return self.random.randint(0, 10)
            
            # 14. Total Sold (chance 70% generate Zero '0')
            def random_totalSold(self):
                if random.random() < 0.7: # 70% chance
                    return 0
                else:
                    return self.random.randint(0, 10)

            # 13. Sold (chance 85% generate Zero '0')
                # if 'total sold' = 0, 100% it generates Zero '0',
                # if 'total sold' > 0, 10% chance 'sold' column generates 1 or 2 in value,
                # and 2% chance generates the equal value as 'total sold' column.
            def random_sold(self, total_sold):
                if total_sold == 0:
                    return 0 # 100% zero if total sold is 0
                
                chance = random.random()
                if chance < 0.10: # 10% chance generate 1 or 2
                    return self.random.randint(1, 2)
                elif chance < 0.12: # Next 2% chance (from 10% to 12%) equal to total sold column
                    return total_sold
                else:
                    return 0 # remaining 88% chance is 0

            # For Float (Decimals)
            #def random_float(self):
                #return round(self.random.uniform(0.00, 100.00),2)

        # Give each random Integer Statistics with Variables
        statistics = MyRandomNumber()
        outcome = statistics.random_outcome()
        income = statistics.random_income()
        topPage = statistics.random_topPage()
        view = statistics.random_view()
        click = statistics.random_click()
        totalSold = statistics.random_totalSold()
        sold = statistics.random_sold(totalSold)

        # To Calculate particular Numbers (Example: Click Percentage)
        # 6. Ads Effectiveness in Total
        try:
            adsEffectivenessInTotal = round(income / outcome)
        except ZeroDivisionError:
            adsEffectivenessInTotal = 0
        # 7. Ads Effectiveness
        if adsEffectivenessInTotal > 0:
            adsEffectiveness = adsEffectivenessInTotal
        else:
            adsEffectiveness = 0
        # 8. Performance
        try:
            performance = round(topPage / view)
        except ZeroDivisionError:
            performance = 0
        # 12. Click Percentage
        try:
            clickPercentage = round(float((click / view) * 100),2)
        except ZeroDivisionError:
            clickPercentage = 0
        # 15. Percentage Sold
        try:
            percentageSold = round(float(totalSold / click))
        except ZeroDivisionError:
            percentageSold = 0
        # 16. Average
        try:
            average = round(outcome / click)
        except ZeroDivisionError:
            average = 0

        writer.writerow([product_category, product_name, outcome, income, adsEffectivenessInTotal, adsEffectiveness, performance, topPage, view, click, clickPercentage, sold, totalSold, percentageSold, average])

print(os.getcwd())
print("✅ CSV file '1_hasil_laporan_iklan_platform_a.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '1_hasil_laporan_iklan_platform_a.csv' has been created successfully!

# %% [markdown]
# #### 3.2. Hasil Laporan 'Iklan Produk Rekomendasi Platform A'

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('csv_forSQLTable/platform_a/2_iklan_produk_direkomendasi_platform_a.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['namaGrup', 'namaProduk', 'pengeluaran', 'pendapatan', 'totalEfektivitasIklan', 'efektivitasIklan', 'performaTampil', 'tampilTeratas', 'tampil', 'klik', 'persentaseKlik', 'terjual', 'totTerjual', 'persentaseTerjual', 'rataRata'])

    for i in range(1, 89):
        # To Generate Random Strings
        # 1. Product Group
        # 2. Product Name
        # 3. Keywords
        product_category = ['dish', 'drink', 'fruit', 'spices', 'vegetable']
        product_category = g.random.choice(product_category)

        if product_category == 'dish':
            product_name = g.food.dish()
            dish_random = [f'Delicious {product_name}', f'Home made {product_name} dishes', f'{product_name} that makes Hungry']
            product_keyword = g.random.choice(dish_random)
        elif product_category == 'drink':
            product_name = g.food.drink()
            drink_random = [f'{product_name} for rehydration', f'Fresh and Cold {product_name}', f'Refreshingly {product_name} drink']
            product_keyword = g.random.choice(drink_random)
        elif product_category == 'fruit':
            product_name = g.food.fruit()
            fruit_random = [f'{product_name} moodbooster', f'Colorful and healthy {product_name}', f'{product_name} that refreshes your mind']
            product_keyword = g.random.choice(fruit_random)
        elif product_category == 'spices':
            product_name = g.food.spices()
            spices_random = [f'Colourful {product_name} spice', f'{product_name} flavoring', f'Family Recommend {product_name}', f'Hot and Spicy {product_name}']
            product_keyword = g.random.choice(spices_random)
        elif product_category == 'vegetable':
            product_name = g.food.vegetable()
            vegetable_random = [f'Healthy {product_name} vegetables', f'{product_name} perfect for vegetarians', f'Fully Green {product_name}']
            product_keyword = g.random.choice(vegetable_random)

        # To Generate The Statistics Random Number (for Int and Float)
        class MyRandomNumber(BaseProvider):
            class Meta:
                name = 'randomNumber'
            
            # 4. Random Outcome $
            def random_outcome(self):
                return self.random.randint(0, 20000)

            # 5. Random Income $
            def random_income(self):
                return self.random.randint(30000, 500000)

            # 9. Show on Top Page
            def random_topPage(self):
                return self.random.randint(0, 300)

            # 10. Views
            def random_view(self):
                return self.random.randint(0, 700)
            
            # 11. Click
            def random_click(self):
                return self.random.randint(0, 10)
            
            # 14. Total Sold (chance 70% generate Zero '0')
            def random_totalSold(self):
                if random.random() < 0.7: # 70% chance
                    return 0
                else:
                    return self.random.randint(0, 10)

            # 13. Sold (chance 85% generate Zero '0')
                # if 'total sold' = 0, 100% it generates Zero '0',
                # if 'total sold' > 0, 10% chance 'sold' column generates 1 or 2 in value,
                # and 2% chance generates the equal value as 'total sold' column.
            def random_sold(self, total_sold):
                if total_sold == 0:
                    return 0 # 100% zero if total sold is 0
                
                chance = random.random()
                if chance < 0.10: # 10% chance generate 1 or 2
                    return self.random.randint(1, 2)
                elif chance < 0.12: # Next 2% chance (from 10% to 12%) equal to total sold column
                    return total_sold
                else:
                    return 0 # remaining 88% chance is 0

            # For Float (Decimals)
            #def random_float(self):
                #return round(self.random.uniform(0.00, 100.00),2)

        # Give each random Integer Statistics with Variables
        statistics = MyRandomNumber()
        outcome = statistics.random_outcome()
        income = statistics.random_income()
        topPage = statistics.random_topPage()
        view = statistics.random_view()
        click = statistics.random_click()
        totalSold = statistics.random_totalSold()
        sold = statistics.random_sold(totalSold)

        # To Calculate particular Numbers (Example: Click Percentage)
        # 6. Ads Effectiveness in Total
        try:
            adsEffectivenessInTotal = round(income / outcome)
        except ZeroDivisionError:
            adsEffectivenessInTotal = 0
        # 7. Ads Effectiveness
        if adsEffectivenessInTotal > 0:
            adsEffectiveness = adsEffectivenessInTotal
        else:
            adsEffectiveness = 0
        # 8. Performance
        try:
            performance = round(topPage / view)
        except ZeroDivisionError:
            performance = 0
        # 12. Click Percentage
        try:
            clickPercentage = round(float((click / view) * 100),2)
        except ZeroDivisionError:
            clickPercentage = 0
        # 15. Percentage Sold
        try:
            percentageSold = round(float(totalSold / click))
        except ZeroDivisionError:
            percentageSold = 0
        # 16. Average
        try:
            average = round(outcome / click)
        except ZeroDivisionError:
            average = 0

        writer.writerow([product_category, product_name, outcome, income, adsEffectivenessInTotal, adsEffectiveness, performance, topPage, view, click, clickPercentage, sold, totalSold, percentageSold, average])

print(os.getcwd())
print("✅ CSV file '2_iklan_produk_direkomendasi_platform_a.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '2_iklan_produk_direkomendasi_platform_a.csv' has been created successfully!

# %% [markdown]
# #### 3.3. Hasil Pencarian 'Iklan Produk di Pencarian Platform A'

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('csv_forSQLTable/platform_a/3_iklan_produk_pencarian_platform_a.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['namaGrup', 'namaProduk', 'pengeluaran', 'pendapatan', 'totalEfektivitasIklan', 'efektivitasIklan', 'performaTampil', 'tampilTeratas', 'tampil', 'klik', 'persentaseKlik', 'terjual', 'totTerjual', 'persentaseTerjual', 'rataRata'])

    for i in range(1, 119):
        # To Generate Random Strings
        # 1. Product Group
        # 2. Product Name
        # 3. Keywords
        product_category = ['dish', 'drink', 'fruit', 'spices', 'vegetable']
        product_category = g.random.choice(product_category)

        if product_category == 'dish':
            product_name = g.food.dish()
            dish_random = [f'Delicious {product_name}', f'Home made {product_name} dishes', f'{product_name} that makes Hungry']
            product_keyword = g.random.choice(dish_random)
        elif product_category == 'drink':
            product_name = g.food.drink()
            drink_random = [f'{product_name} for rehydration', f'Fresh and Cold {product_name}', f'Refreshingly {product_name} drink']
            product_keyword = g.random.choice(drink_random)
        elif product_category == 'fruit':
            product_name = g.food.fruit()
            fruit_random = [f'{product_name} moodbooster', f'Colorful and healthy {product_name}', f'{product_name} that refreshes your mind']
            product_keyword = g.random.choice(fruit_random)
        elif product_category == 'spices':
            product_name = g.food.spices()
            spices_random = [f'Colourful {product_name} spice', f'{product_name} flavoring', f'Family Recommend {product_name}', f'Hot and Spicy {product_name}']
            product_keyword = g.random.choice(spices_random)
        elif product_category == 'vegetable':
            product_name = g.food.vegetable()
            vegetable_random = [f'Healthy {product_name} vegetables', f'{product_name} perfect for vegetarians', f'Fully Green {product_name}']
            product_keyword = g.random.choice(vegetable_random)

        # To Generate The Statistics Random Number (for Int and Float)
        class MyRandomNumber(BaseProvider):
            class Meta:
                name = 'randomNumber'
            
            # 4. Random Outcome $
            def random_outcome(self):
                return self.random.randint(0, 20000)

            # 5. Random Income $
            def random_income(self):
                return self.random.randint(30000, 500000)

            # 9. Show on Top Page
            def random_topPage(self):
                return self.random.randint(0, 300)

            # 10. Views
            def random_view(self):
                return self.random.randint(0, 700)
            
            # 11. Click
            def random_click(self):
                return self.random.randint(0, 10)
            
            # 14. Total Sold (chance 70% generate Zero '0')
            def random_totalSold(self):
                if random.random() < 0.7: # 70% chance
                    return 0
                else:
                    return self.random.randint(0, 10)

            # 13. Sold (chance 85% generate Zero '0')
                # if 'total sold' = 0, 100% it generates Zero '0',
                # if 'total sold' > 0, 10% chance 'sold' column generates 1 or 2 in value,
                # and 2% chance generates the equal value as 'total sold' column.
            def random_sold(self, total_sold):
                if total_sold == 0:
                    return 0 # 100% zero if total sold is 0
                
                chance = random.random()
                if chance < 0.10: # 10% chance generate 1 or 2
                    return self.random.randint(1, 2)
                elif chance < 0.12: # Next 2% chance (from 10% to 12%) equal to total sold column
                    return total_sold
                else:
                    return 0 # remaining 88% chance is 0

            # For Float (Decimals)
            #def random_float(self):
                #return round(self.random.uniform(0.00, 100.00),2)

        # Give each random Integer Statistics with Variables
        statistics = MyRandomNumber()
        outcome = statistics.random_outcome()
        income = statistics.random_income()
        topPage = statistics.random_topPage()
        view = statistics.random_view()
        click = statistics.random_click()
        totalSold = statistics.random_totalSold()
        sold = statistics.random_sold(totalSold)

        # To Calculate particular Numbers (Example: Click Percentage)
        # 6. Ads Effectiveness in Total
        try:
            adsEffectivenessInTotal = round(income / outcome)
        except ZeroDivisionError:
            adsEffectivenessInTotal = 0
        # 7. Ads Effectiveness
        if adsEffectivenessInTotal > 0:
            adsEffectiveness = adsEffectivenessInTotal
        else:
            adsEffectiveness = 0
        # 8. Performance
        try:
            performance = round(topPage / view)
        except ZeroDivisionError:
            performance = 0
        # 12. Click Percentage
        try:
            clickPercentage = round(float((click / view) * 100),2)
        except ZeroDivisionError:
            clickPercentage = 0
        # 15. Percentage Sold
        try:
            percentageSold = round(float(totalSold / click))
        except ZeroDivisionError:
            percentageSold = 0
        # 16. Average
        try:
            average = round(outcome / click)
        except ZeroDivisionError:
            average = 0

        writer.writerow([product_category, product_name, outcome, income, adsEffectivenessInTotal, adsEffectiveness, performance, topPage, view, click, clickPercentage, sold, totalSold, percentageSold, average])

print(os.getcwd())
print("✅ CSV file '3_iklan_produk_pencarian_platform_a.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '3_iklan_produk_pencarian_platform_a.csv' has been created successfully!

# %% [markdown]
# #### 3.4. Hasil Pencarian 'Iklan Toko Platform A'

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('csv_forSQLTable/platform_a/4_iklan_toko_platform_a.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['namaGrup', 'pengeluaran', 'pendapatan', 'performaTampil', 'tampilTeratas', 'tampil', 'klik', 'persentaseKlik', 'totTerjual', 'persentaseTerjual', 'rataRata'])
    for i in range(1, 4):
        # To Generate Random Strings
        # 1. Product Group
        # 2. Product Name
        # 3. Keywords
        product_category = ['dish', 'drink', 'fruit', 'spices', 'vegetable']
        product_category = g.random.choice(product_category)

        # To Generate The Statistics Random Number (for Int and Float)
        class MyRandomNumber(BaseProvider):
            class Meta:
                name = 'randomNumber'

            # 4. Random Outcome $
            def random_outcome(self):
                return self.random.randint(0, 20000)

            # 5. Random Income $
            def random_income(self):
                return self.random.randint(30000, 500000)

            # 9. Show on Top Page
            def random_topPage(self):
                return self.random.randint(0, 300)

            # 10. Views
            def random_view(self):
                return self.random.randint(0, 700)
            
            # 11. Click
            def random_click(self):
                return self.random.randint(0, 10)
            
            # 14. Total Sold (chance 70% generate Zero '0')
            def random_totalSold(self):
                if random.random() < 0.7: # 70% chance
                    return 0
                else:
                    return self.random.randint(0, 10)

        # Give each random Integer Statistics with Variables
        statistics = MyRandomNumber()
        outcome = statistics.random_outcome()
        income = statistics.random_income()
        topPage = statistics.random_topPage()
        view = statistics.random_view()
        click = statistics.random_click()
        totalSold = statistics.random_totalSold()

        # To Calculate particular Numbers (Example: Click Percentage)

        # 8. Performance
        try:
            performance = round(topPage / view)
        except ZeroDivisionError:
            performance = 0
        # 12. Click Percentage
        try:
            clickPercentage = round(float((click / view) * 100),2)
        except ZeroDivisionError:
            clickPercentage = 0
        # 15. Percentage Sold
        try:
            percentageSold = round(float(totalSold / click))
        except ZeroDivisionError:
            percentageSold = 0
        # 16. Average
        try:
            average = round(outcome / click)
        except ZeroDivisionError:
            average = 0

        writer.writerow([product_category, outcome, income, performance, topPage, view, click, clickPercentage, totalSold, percentageSold, average])

print(os.getcwd())
print("✅ CSV file '4_iklan_toko_platform_a.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '4_iklan_toko_platform_a.csv' has been created successfully!

# %% [markdown]
# #### 3.5. Hasil Pencarian 'Kata Kunci Platform A'

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('csv_forSQLTable/platform_a/5_kata_kunci_platform_a.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['namaGrup', 'kataKunci', 'pengeluaran', 'pendapatan', 'totalEfektivitasIklan', 'efektivitasIklan', 'tampil', 'klik', 'persentaseKlik', 'terjual', 'totTerjual', 'rataRata', 'tampilTeratas'])

    for i in range(1, 731):
        # To Generate Random Strings
        # 1. Product Group
        # 2. Product Name
        # 3. Keywords
        product_category = ['dish', 'drink', 'fruit', 'spices', 'vegetable']
        product_category = g.random.choice(product_category)

        if product_category == 'dish':
            product_name = g.food.dish()
            dish_random = [f'Delicious {product_name}', f'Home made {product_name} dishes', f'{product_name} that makes Hungry']
            product_keyword = g.random.choice(dish_random)
        elif product_category == 'drink':
            product_name = g.food.drink()
            drink_random = [f'{product_name} for rehydration', f'Fresh and Cold {product_name}', f'Refreshingly {product_name} drink']
            product_keyword = g.random.choice(drink_random)
        elif product_category == 'fruit':
            product_name = g.food.fruit()
            fruit_random = [f'{product_name} moodbooster', f'Colorful and healthy {product_name}', f'{product_name} that refreshes your mind']
            product_keyword = g.random.choice(fruit_random)
        elif product_category == 'spices':
            product_name = g.food.spices()
            spices_random = [f'Colourful {product_name} spice', f'{product_name} flavoring', f'Family Recommend {product_name}', f'Hot and Spicy {product_name}']
            product_keyword = g.random.choice(spices_random)
        elif product_category == 'vegetable':
            product_name = g.food.vegetable()
            vegetable_random = [f'Healthy {product_name} vegetables', f'{product_name} perfect for vegetarians', f'Fully Green {product_name}']
            product_keyword = g.random.choice(vegetable_random)

        # To Generate The Statistics Random Number (for Int and Float)
        class MyRandomNumber(BaseProvider):
            class Meta:
                name = 'randomNumber'

            # 4. Random Outcome $
            def random_outcome(self):
                return self.random.randint(0, 20000)

            # 5. Random Income $
            def random_income(self):
                return self.random.randint(30000, 500000)

            # 9. Show on Top Page
            def random_topPage(self):
                return self.random.randint(0, 300)

            # 10. Views
            def random_view(self):
                return self.random.randint(0, 700)
            
            # 11. Click
            def random_click(self):
                return self.random.randint(0, 10)
            
            # 14. Total Sold (chance 70% generate Zero '0')
            def random_totalSold(self):
                if random.random() < 0.7: # 70% chance
                    return 0
                else:
                    return self.random.randint(0, 10)

            # 13. Sold (chance 85% generate Zero '0')
                # if 'total sold' = 0, 100% it generates Zero '0',
                # if 'total sold' > 0, 10% chance 'sold' column generates 1 or 2 in value,
                # and 2% chance generates the equal value as 'total sold' column.
            def random_sold(self, total_sold):
                if total_sold == 0:
                    return 0 # 100% zero if total sold is 0
                
                chance = random.random()
                if chance < 0.10: # 10% chance generate 1 or 2
                    return self.random.randint(1, 2)
                elif chance < 0.12: # Next 2% chance (from 10% to 12%) equal to total sold column
                    return total_sold
                else:
                    return 0 # remaining 88% chance is 0

            # For Float (Decimals)
            #def random_float(self):
                #return round(self.random.uniform(0.00, 100.00),2)

        # Give each random Integer Statistics with Variables
        statistics = MyRandomNumber()
        outcome = statistics.random_outcome()
        income = statistics.random_income()
        topPage = statistics.random_topPage()
        view = statistics.random_view()
        click = statistics.random_click()
        totalSold = statistics.random_totalSold()
        sold = statistics.random_sold(totalSold)

        # To Calculate particular Numbers (Example: Click Percentage)
        # 6. Ads Effectiveness in Total
        try:
            adsEffectivenessInTotal = round(income / outcome)
        except ZeroDivisionError:
            adsEffectivenessInTotal = 0
        # 7. Ads Effectiveness
        if adsEffectivenessInTotal > 0:
            adsEffectiveness = adsEffectivenessInTotal
        else:
            adsEffectiveness = 0
        # 12. Click Percentage
        try:
            clickPercentage = round(float((click / view) * 100),2)
        except ZeroDivisionError:
            clickPercentage = 0
        # 16. Average
        try:
            average = round(outcome / click)
        except ZeroDivisionError:
            average = 0
            
        writer.writerow([product_category, product_keyword, outcome, income, adsEffectivenessInTotal, adsEffectiveness, view, click, clickPercentage, sold, totalSold, average, topPage])

print(os.getcwd())
print("✅ CSV file '5_kata_kunci_platform_a.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis\mimesis_experiment
# ✅ CSV file '5_kata_kunci_platform_a.csv' has been created successfully!

# %% [markdown]
# ### 4 - Kelompok Iklan Platform B

# %% [markdown]
# Sekumpulan Tabel dari Hasil Laporan Iklan Platform B

# %% [markdown]
# #### Generate Random Number

# %% [markdown]
# <b>Example:</b> Creating Dummy Data for Foreign Konstraints (FKs), but in this case there are Too Many Rows that makes you confused

# %% [markdown]
# To help ease decision making while deciding what rows that need to be inserted by 2 for example, if the whole rows are 1, But there are very very plenty of rows.

# %% [markdown]
# Feel free to change the row count (i), the random.random() chance probability on printing the number, and the number itself (I use 1 and 2), you want to change to 11 and 12 for example, fine. As you need

# %% [markdown]
# #### For FK with 2 Choices

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# To Generate The Statistics Random Number (for Int and Float)

for i in range(0, 10):

    if random.random() < 0.05: # 5% chance it generates 2
        number = 2
    else: # 95% chance it generates 1
        number = 1

    print(f'Row: {i+1}, FK Number: {number}')

    # Result:
    # Rows 1, FK Number: 1
    # Rows 2, FK Number: 1
    # Rows 3, FK Number: 1
    # Rows 4, FK Number: 1
    # Rows 5, FK Number: 1
    # Rows 6, FK Number: 1
    # Rows 7, FK Number: 1
    # Rows 8, FK Number: 1
    # Rows 9, FK Number: 2
    # Rows 10, FK Number: 1
    # and so on, and so on...
# Out:
# Row: 1, FK Number: 1
# Row: 2, FK Number: 1
# Row: 3, FK Number: 1
# Row: 4, FK Number: 1
# Row: 5, FK Number: 1
# Row: 6, FK Number: 1
# Row: 7, FK Number: 1
# Row: 8, FK Number: 1
# Row: 9, FK Number: 1
# Row: 10, FK Number: 1

# %% [markdown]
# #### For FK with 3 Choices

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# To Generate The Statistics Random Number (for Int and Float)

for i in range(0,10):

    if random.random() < 0.1: # 10% chance it generates 1
        number = 1
    elif random.random() < 0.4: #20% chance it generates 2
        number = 2
    else: # 70% chance it generates 3
        number = 3

    print(f'Row: {i+1}, FK Number: {number}')
# Out:
# Row: 2, FK Number: 3
# Row: 3, FK Number: 2
# Row: 4, FK Number: 1
# Row: 5, FK Number: 3
# Row: 6, FK Number: 3
# Row: 7, FK Number: 3
# Row: 8, FK Number: 1
# Row: 9, FK Number: 2
# Row: 10, FK Number: 1
# Row: 11, FK Number: 3
# Row: 12, FK Number: 3
# Row: 13, FK Number: 3
# Row: 14, FK Number: 2
# Row: 15, FK Number: 1
# Row: 16, FK Number: 1
# Row: 17, FK Number: 1
# Row: 18, FK Number: 3
# Row: 19, FK Number: 3
# Row: 20, FK Number: 1
# Row: 21, FK Number: 1
# Row: 22, FK Number: 3
# Row: 23, FK Number: 3
# Row: 24, FK Number: 3
# Row: 25, FK Number: 1
# Row: 26, FK Number: 2
# Row: 27, FK Number: 1
# Row: 28, FK Number: 3
# Row: 29, FK Number: 3
# Row: 30, FK Number: 3
# Row: 31, FK Number: 1
# Row: 32, FK Number: 1
# Row: 33, FK Number: 3
# Row: 34, FK Number: 1
# Row: 35, FK Number: 1
# Row: 36, FK Number: 1
# Row: 37, FK Number: 3
# Row: 38, FK Number: 1
# Row: 39, FK Number: 1
# Row: 40, FK Number: 3
# Row: 41, FK Number: 2
# Row: 42, FK Number: 3
# Row: 43, FK Number: 3
# Row: 44, FK Number: 1
# Row: 45, FK Number: 1
# Row: 46, FK Number: 3
# Row: 47, FK Number: 3
# Row: 48, FK Number: 1
