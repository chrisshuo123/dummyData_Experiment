# %%
from mimesis import Generic
from mimesis.locales import Locale

generic = Generic(locale=Locale.EN)

# Example product categories (you can customize or randomize these)
categories = ['Electronics', 'Clothing', 'Home Appliances', 'Books', 'Toys']

# Generate a random category
product_category = generic.random.choice(categories)

# Generate a random product name
# Title creates a phrase-like product name (capitalized)
product_name = generic.text.title()

# Or combine random words manually
word1 = generic.text.word().capitalize()
word2 = generic.text.word().capitalize()
product_name_alt = f"{word1} {word2}"

# Final output
print(f"Category: {product_category}")
print(f"Product Name (title): {product_name}")
print(f"Product Name (word combination): {product_name_alt}")
# Out:
# Category: Clothing
# Product Name (title): Erlang is a general-purpose, concurrent, functional programming language.
# Product Name (word combination): Drugs Thousand

# %% [markdown]
# ### Generate for 120 Rows

# %%
from mimesis import Generic
from mimesis.locales import Locale

generic = Generic(locale=Locale.EN)

# Example product categories (you can customize or randomize these)
categories = ['Electronics', 'Clothing', 'Home Appliances', 'Books', 'Toys']

# Generate a random category
for i in range(1,121):
    product_category = generic.random.choice(categories)
    product_name = generic.text.title()
    print(f"{i}. Category: {product_category} | Product Name: {product_name}")
# Out:
# 1. Category: Books | Product Name: The arguments can be primitive data types or compound data types.
# 2. Category: Toys | Product Name: They are written as strings of consecutive alphanumeric characters, the first character being lowercase.
# 3. Category: Clothing | Product Name: The syntax {D1,D2,...,Dn} denotes a tuple whose arguments are D1, D2, ... Dn.
# 4. Category: Books | Product Name: It is also a garbage-collected runtime system.
# 5. Category: Electronics | Product Name: Atoms can contain any character if they are enclosed within single quotes and an escape convention exists which allows any character to be used within an atom.
# 6. Category: Books | Product Name: Messages can be sent to and received from ports, but these messages must obey the so-called "port protocol."
# 7. Category: Home Appliances | Product Name: In 1989 the building was heavily damaged by fire, but it has since been restored.
# 8. Category: Home Appliances | Product Name: Haskell is a standardized, general-purpose purely functional programming language, with non-strict semantics and strong static typing.
# 9. Category: Clothing | Product Name: Atoms can contain any character if they are enclosed within single quotes and an escape convention exists which allows any character to be used within an atom.
# 10. Category: Clothing | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 11. Category: Home Appliances | Product Name: Ports are created with the built-in function open_port.
# 12. Category: Books | Product Name: He looked inquisitively at his keyboard and wrote another sentence.
# 13. Category: Home Appliances | Product Name: The arguments can be primitive data types or compound data types.
# 14. Category: Clothing | Product Name: Ports are used to communicate with the external world.
# 15. Category: Electronics | Product Name: The Galactic Empire is nearing completion of the Death Star, a space station with the power to destroy entire planets.
# 16. Category: Books | Product Name: Ports are used to communicate with the external world.
# 17. Category: Books | Product Name: He looked inquisitively at his keyboard and wrote another sentence.
# 18. Category: Clothing | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 19. Category: Toys | Product Name: The syntax {D1,D2,...,Dn} denotes a tuple whose arguments are D1, D2, ... Dn.
# 20. Category: Home Appliances | Product Name: In 1989 the building was heavily damaged by fire, but it has since been restored.
# 21. Category: Home Appliances | Product Name: Tuples are containers for a fixed number of Erlang data types.
# 22. Category: Books | Product Name: Do you have any idea why this is not working?
# 23. Category: Electronics | Product Name: Erlang is known for its designs that are well suited for systems.
# 24. Category: Books | Product Name: Where are my pants?
# 25. Category: Electronics | Product Name: Ports are used to communicate with the external world.
# 26. Category: Books | Product Name: Haskell features a type system with type inference and lazy evaluation.
# 27. Category: Toys | Product Name: I don't even care.
# 28. Category: Clothing | Product Name: Do you come here often?
# 29. Category: Books | Product Name: Messages can be sent to and received from ports, but these messages must obey the so-called "port protocol."
# 30. Category: Clothing | Product Name: The Galactic Empire is nearing completion of the Death Star, a space station with the power to destroy entire planets.
# 31. Category: Clothing | Product Name: Make me a sandwich.
# 32. Category: Books | Product Name: Ports are used to communicate with the external world.
# 33. Category: Clothing | Product Name: Ports are created with the built-in function open_port.
# 34. Category: Books | Product Name: Its main implementation is the Glasgow Haskell Compiler.
# 35. Category: Home Appliances | Product Name: Atoms are used within a program to denote distinguished values.
# 36. Category: Books | Product Name: Ports are used to communicate with the external world.
# 37. Category: Toys | Product Name: He looked inquisitively at his keyboard and wrote another sentence.
# 38. Category: Clothing | Product Name: She spent her earliest years reading classic literature, and writing poetry.
# 39. Category: Books | Product Name: Ports are created with the built-in function open_port.
# 40. Category: Toys | Product Name: I don't even care.
# 41. Category: Clothing | Product Name: The syntax {D1,D2,...,Dn} denotes a tuple whose arguments are D1, D2, ... Dn.
# 42. Category: Books | Product Name: Ports are used to communicate with the external world.
# 43. Category: Electronics | Product Name: Do you come here often?
# 44. Category: Toys | Product Name: The sequential subset of Erlang supports eager evaluation, single assignment, and dynamic typing.
# 45. Category: Home Appliances | Product Name: He looked inquisitively at his keyboard and wrote another sentence.
# 46. Category: Electronics | Product Name: She spent her earliest years reading classic literature, and writing poetry.
# 47. Category: Electronics | Product Name: Atoms can contain any character if they are enclosed within single quotes and an escape convention exists which allows any character to be used within an atom.
# 48. Category: Books | Product Name: It is also a garbage-collected runtime system.
# 49. Category: Clothing | Product Name: The arguments can be primitive data types or compound data types.
# 50. Category: Home Appliances | Product Name: Tuples are containers for a fixed number of Erlang data types.
# 51. Category: Books | Product Name: Haskell features a type system with type inference and lazy evaluation.
# 52. Category: Books | Product Name: They are written as strings of consecutive alphanumeric characters, the first character being lowercase.
# 53. Category: Clothing | Product Name: They are written as strings of consecutive alphanumeric characters, the first character being lowercase.
# 54. Category: Toys | Product Name: In 1989 the building was heavily damaged by fire, but it has since been restored.
# 55. Category: Clothing | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 56. Category: Electronics | Product Name: In 1989 the building was heavily damaged by fire, but it has since been restored.
# 57. Category: Clothing | Product Name: The arguments can be primitive data types or compound data types.
# 58. Category: Toys | Product Name: The Galactic Empire is nearing completion of the Death Star, a space station with the power to destroy entire planets.
# 59. Category: Toys | Product Name: Where are my pants?
# 60. Category: Books | Product Name: I don't even care.
# 61. Category: Books | Product Name: Its main implementation is the Glasgow Haskell Compiler.
# 62. Category: Toys | Product Name: Where are my pants?
# 63. Category: Toys | Product Name: Atoms can contain any character if they are enclosed within single quotes and an escape convention exists which allows any character to be used within an atom.
# 64. Category: Electronics | Product Name: Haskell is a standardized, general-purpose purely functional programming language, with non-strict semantics and strong static typing.
# 65. Category: Toys | Product Name: The arguments can be primitive data types or compound data types.
# 66. Category: Clothing | Product Name: Haskell is a standardized, general-purpose purely functional programming language, with non-strict semantics and strong static typing.
# 67. Category: Books | Product Name: Do you come here often?
# 68. Category: Home Appliances | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 69. Category: Toys | Product Name: Where are my pants?
# 70. Category: Books | Product Name: Haskell features a type system with type inference and lazy evaluation.
# 71. Category: Books | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 72. Category: Books | Product Name: Ports are used to communicate with the external world.
# 73. Category: Electronics | Product Name: The syntax {D1,D2,...,Dn} denotes a tuple whose arguments are D1, D2, ... Dn.
# 74. Category: Books | Product Name: It is also a garbage-collected runtime system.
# 75. Category: Home Appliances | Product Name: Where are my pants?
# 76. Category: Clothing | Product Name: Do you come here often?
# 77. Category: Toys | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 78. Category: Home Appliances | Product Name: Make me a sandwich.
# 79. Category: Clothing | Product Name: She spent her earliest years reading classic literature, and writing poetry.
# 80. Category: Toys | Product Name: Ports are created with the built-in function open_port.
# 81. Category: Home Appliances | Product Name: Erlang is known for its designs that are well suited for systems.
# 82. Category: Books | Product Name: Ports are used to communicate with the external world.
# 83. Category: Toys | Product Name: Messages can be sent to and received from ports, but these messages must obey the so-called "port protocol."
# 84. Category: Clothing | Product Name: Haskell features a type system with type inference and lazy evaluation.
# 85. Category: Clothing | Product Name: Its main implementation is the Glasgow Haskell Compiler.
# 86. Category: Electronics | Product Name: Erlang is known for its designs that are well suited for systems.
# 87. Category: Clothing | Product Name: I don't even care.
# 88. Category: Books | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 89. Category: Home Appliances | Product Name: The Galactic Empire is nearing completion of the Death Star, a space station with the power to destroy entire planets.
# 90. Category: Home Appliances | Product Name: Make me a sandwich.
# 91. Category: Electronics | Product Name: Haskell is a standardized, general-purpose purely functional programming language, with non-strict semantics and strong static typing.
# 92. Category: Electronics | Product Name: Atoms can contain any character if they are enclosed within single quotes and an escape convention exists which allows any character to be used within an atom.
# 93. Category: Home Appliances | Product Name: Any element of a tuple can be accessed in constant time.
# 94. Category: Books | Product Name: Atoms are used within a program to denote distinguished values.
# 95. Category: Home Appliances | Product Name: Ports are used to communicate with the external world.
# 96. Category: Books | Product Name: Haskell is a standardized, general-purpose purely functional programming language, with non-strict semantics and strong static typing.
# 97. Category: Clothing | Product Name: Erlang is known for its designs that are well suited for systems.
# 98. Category: Home Appliances | Product Name: Where are my pants?
# 99. Category: Books | Product Name: Tuples are containers for a fixed number of Erlang data types.
# 100. Category: Clothing | Product Name: Haskell features a type system with type inference and lazy evaluation.
# 101. Category: Books | Product Name: Atoms are used within a program to denote distinguished values.
# 102. Category: Books | Product Name: Type classes first appeared in the Haskell programming language.
# 103. Category: Clothing | Product Name: Where are my pants?
# 104. Category: Home Appliances | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 105. Category: Clothing | Product Name: Erlang is a general-purpose, concurrent, functional programming language.
# 106. Category: Electronics | Product Name: Ports are created with the built-in function open_port.
# 107. Category: Home Appliances | Product Name: Atoms can contain any character if they are enclosed within single quotes and an escape convention exists which allows any character to be used within an atom.
# 108. Category: Books | Product Name: The sequential subset of Erlang supports eager evaluation, single assignment, and dynamic typing.
# 109. Category: Toys | Product Name: He looked inquisitively at his keyboard and wrote another sentence.
# 110. Category: Books | Product Name: He looked inquisitively at his keyboard and wrote another sentence.
# 111. Category: Home Appliances | Product Name: Its main implementation is the Glasgow Haskell Compiler.
# 112. Category: Home Appliances | Product Name: Ports are created with the built-in function open_port.
# 113. Category: Home Appliances | Product Name: Erlang is known for its designs that are well suited for systems.
# 114. Category: Home Appliances | Product Name: Where are my pants?
# 115. Category: Electronics | Product Name: Type classes first appeared in the Haskell programming language.
# 116. Category: Home Appliances | Product Name: They are written as strings of consecutive alphanumeric characters, the first character being lowercase.
# 117. Category: Toys | Product Name: The arguments can be primitive data types or compound data types.
# 118. Category: Books | Product Name: They are written as strings of consecutive alphanumeric characters, the first character being lowercase.
# 119. Category: Clothing | Product Name: She spent her earliest years reading classic literature, and writing poetry.
# 120. Category: Books | Product Name: The sequential subset of Erlang supports eager evaluation, single assignment, and dynamic typing.

# %% [markdown]
# ### Generate to CSV Files

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis.locales import Locale

generic = Generic(locale=Locale.EN)

# Example product categories
categories = ['Electronics', 'Clothing', 'Home Appliances', 'Books', 'Toys']

# Open a CSV file for writing
with open('products.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['No', 'Category', 'Product Name'])

    # Generate and write 120 product entries
    for i in range(1, 121):
        product_category = generic.random.choice(categories)
        sentences_count = random.randint(2, 3)
        product_name = "".join(generic.text.title() for _ in range(sentences_count))
        writer.writerow([i, product_category, product_name])

print(os.getcwd())
print("✅ CSV file 'products.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis
# ✅ CSV file 'products.csv' has been created successfully!

# %% [markdown]
# ## Food Categories

# %%
import csv
import os
from mimesis import Generic
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# Open a CSV file for writing
with open('products.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['No', 'Category', 'Product Name'])

    # Generate and write 120 product entries
    for i in range(1, 21):
        product_category = 'Dish'
        product_name = g.food.dish()
        writer.writerow([i, product_category, product_name])
    
    for i in range(21, 51):
        product_category = 'Vegetable'
        product_name = g.food.vegetable()
        writer.writerow([i, product_category, product_name])

    for i in range(51, 61):
        product_category = 'Dish'
        product_name = g.food.dish()
        writer.writerow([i, product_category, product_name])

    for i in range(61, 66):
        product_category = 'Fruit'
        product_name = g.food.fruit()
        writer.writerow([i, product_category, product_name])

    for i in range(66, 71):
        product_category = 'drink'
        product_name = g.food.drink()
        writer.writerow([i, product_category, product_name])

    for i in range(71, 76):
        product_category = 'vegetable'
        product_name = g.food.vegetable()
        writer.writerow([i, product_category, product_name])

    for i in range(76, 81):
        product_category = 'spices'
        product_name = g.food.spices()
        writer.writerow([i, product_category, product_name])

    for i in range(81, 101):
        product_category = 'fruit'
        product_name = g.food.fruit()
        writer.writerow([i, product_category, product_name])

print(os.getcwd())
print("✅ CSV file 'products.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis
# ✅ CSV file 'products.csv' has been created successfully!

# %% [markdown]
# Another Example, by adding Random Keywords:

# %%
import csv
import random
import os
from mimesis import Generic
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# Example Food categories
#categories = ['Electronics', 'Clothing', 'Home Appliances', 'Books', 'Toys']

# Open a CSV file for writing
with open('products_with_Keywords.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write header row
    writer.writerow(['No', 'Category', 'Product Name', 'Keywords'])

    # Generate and write 120 product entries
    for i in range(1, 21):
        product_category = 'Dish'
        product_name = g.food.dish()
        # Give Random sentences for Keywords
        dish_random = [f'Delicious {product_name}', f'Fully prep {product_name} dishes', f'{product_name} that makes Hungry']
        product_keyword = generic.random.choice(dish_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])
    
    for i in range(21, 51):
        product_category = 'Vegetable'
        product_name = g.food.vegetable()
        # Give Random sentences for Keywords
        vegetable_random = [f'Healthy {product_name}', f'Vegetarian Food {product_name}', f'Fully Green {product_name}']
        product_keyword = generic.random.choice(vegetable_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])

    for i in range(51, 61):
        product_category = 'Dish'
        product_name = g.food.dish()
        # Give Random sentences for Keywords
        dish_random = [f'Delicious {product_name}', f'Home made {product_name} dishes', f'{product_name} that makes Hungry']
        product_keyword = generic.random.choice(dish_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])

    for i in range(61, 66):
        product_category = 'Fruit'
        product_name = g.food.fruit()
        # Give Random sentences for Keywords
        fruit_random = [f'{product_name} moodbooster', f'Colorful and healthy {product_name}', f'{product_name} that refreshes your mind']
        product_keyword = generic.random.choice(fruit_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])

    for i in range(66, 71):
        product_category = 'drink'
        product_name = g.food.drink()
        # Give Random sentences for Keywords
        drink_random = [f'{product_name} for rehydration', f'Fresh and Cold {product_name}', f'Refreshingly {product_name} drink']
        product_keyword = generic.random.choice(drink_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])

    for i in range(71, 76):
        product_category = 'vegetable'
        product_name = g.food.vegetable()
        # Give Random sentences for Keywords
        vegetable_random = [f'Healthy {product_name} vegetables', f'{product_name} perfect for vegetarians', f'Fully Green {product_name}']
        product_keyword = generic.random.choice(vegetable_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])

    for i in range(76, 81):
        product_category = 'spices'
        product_name = g.food.spices()
        # Give Random sentences for Keywords
        spices_random = [f'Colourful {product_name} spice', f'{product_name} flavoring', f'Family Recommend {product_name}', f'Hot and Spicy {product_name}']
        product_keyword = generic.random.choice(spices_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])

    for i in range(81, 101):
        product_category = 'fruit'
        product_name = g.food.fruit()
        # Give Random sentences for Keywords
        fruit_random = [f'{product_name} Moodbooster', f'Colorful and healthy {product_name}', f'{product_name} that soothes the mind']
        product_keyword = generic.random.choice(fruit_random)
        # Output
        writer.writerow([i, product_category, product_name, product_keyword])

print(os.getcwd())
print("✅ CSV file 'products_with_keyword.csv' has been created successfully!")
# Out:
# d:\4 - Masterclass Collections (udemy, seminar, dkk)\34_dataFaking_plugins_github\2_mimesis
# ✅ CSV file 'products_with_keyword.csv' has been created successfully!

# %% [markdown]
# ## Generate Random Integer, Decimals

# %% [markdown]
# URL: <a href="https://mimesis.name/latest/api.html#mimesis.random.Random">https://mimesis.name/latest/api.html#mimesis.random.Random</a>

# %% [markdown]
# <p>URL for the API Random Module: <a href="https://mimesis.name/latest/api.html#mimesis.random.Random">https://mimesis.name/latest/api.html#mimesis.random.Random</a></p>
# <p>URL for random and Seed: <a href="https://mimesis.name/latest/random_and_seed.html">https://mimesis.name/latest/random_and_seed.html</a></p>

# %% [markdown]
# Generate Integer and Float DataTypes

# %%
import random
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

class MyProvider(BaseProvider):

    class Meta:
        name = 'my_provider'

    # For Integer:
    def random_integer(self):
        return self.random.randint(0, 100)
    
    # For Float (Decimals)
    def random_float(self):
        return round(self.random.uniform(0.00, 100.00),2)

my_provider = MyProvider()
print("Int: ",my_provider.random_integer())
print("Float: ", my_provider.random_float())
# Out:
# Int:  55
# Float:  83.55

# %% [markdown]
# Generate Income & Outcome Earnings, with 80% chance of '0' income and outcome

# %%
import random
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

class MyCashflow(BaseProvider):

    class Meta:
        name = 'cashflow'

    # For Integer:
    def random_cashflow(self):
        if random.random() < 0.8: # 80% chance
            return 0
        else: # 20% chance
            return self.random.randint(0, 100000)

cashflow = MyCashflow()
Zero_division_count = 0 # Counter for division-by-zero cases

for i in range(1, 100):
    income = cashflow.random_cashflow()
    outcome = cashflow.random_cashflow()

    if outcome == 0:
        Zero_division_count += 1
        adsEffectiveness = 0
    elif (income < outcome):
        adsEffectiveness = 0
    else:
        adsEffectiveness = round((income / outcome),2)


    print("Income: ", income)
    print("Outcome: ", outcome)
    print("Ads Effectiveness: ", adsEffectiveness)
    print("")
# Out:
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  44554
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  67363
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  20683
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  38016
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  26852
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  92662
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  16715
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  8184
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  88341
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  53498
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  25354
# Ads Effectiveness:  0
#
# Income:  87313
# Outcome:  60168
# Ads Effectiveness:  1.45
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  35136
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  19304
# Ads Effectiveness:  0
#
# Income:  67903
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  95120
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  4046
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  91591
# Outcome:  57054
# Ads Effectiveness:  1.61
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  84437
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  15546
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  50584
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  55392
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  69614
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  85158
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  66846
# Outcome:  31007
# Ads Effectiveness:  2.16
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  42159
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  2102
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  53708
# Ads Effectiveness:  0
#
# Income:  95445
# Outcome:  779
# Ads Effectiveness:  122.52
#
# Income:  0
# Outcome:  99775
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  73082
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  75826
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0
#
# Income:  0
# Outcome:  0
# Ads Effectiveness:  0

# %% [markdown]
# ### View, Click, Ads Effectiveness

# %%
import random
from mimesis import Generic
from mimesis import BaseProvider
from mimesis.locales import Locale
g = Generic(locale=Locale.EN)

# To Generate The Statistics Random Number (for Int and Float)
class MyProvider(BaseProvider):

    class Meta:
        name = 'statistics'

    # Random View Statistic:
    def random_viewStatistics(self):
        return self.random.randint(0, 700)
    
    # Random Click Statistic:
    def random_clickStatistics(self):
        return self.random.randint(0, 10)
    
    # For Float (Decimals)
    def random_float(self):
        return round(self.random.uniform(0.00, 100.00),2)

statistics = MyProvider()

viewStatistics = statistics.random_viewStatistics()
clickStatistics = statistics.random_clickStatistics()

# To Calculate particular Numbers (Example: Click Percentage)
clickPercentage = round(float((clickStatistics / viewStatistics) * 100),2)

print("View: ", viewStatistics)
print("Click: ", clickStatistics)
print("Click Percentage: ", clickPercentage)

#print("Float: ", statistics.random_float())
# Out:
# View:  106
# Click:  7
# Click Percentage:  6.6

# %% [markdown]
# <p>Let's add with more Detailed Approach. Here's the Column:</p>
# <ol>
#     <li>'Product Group' <i>(Random String)</i></li>
#     <li>'Product Name' <i>(Random String)</i></li>
#     <li>'Keyword' <i>(Random String)</i></li>
#     <li>'Outcome' <i>(Random Integer)</i></li>
#     <li>'Income' <i>(Random Integer)</i></li>
#     <li>'Ads Effectiveness in Total' <i>(income / outcome)</i></li>
#     <li>'Ads Effectiveness' <i>(Show if 'Sold' is shown)</i></li>
#     <li>'Performance' <i>(Show on Top Page / Views)</i></li>
#     <li>'Show on Top Page' <i>(Random Integer)</i></li>
#     <li>'Views' <i>(Random Integer)</i></li>
#     <li>'Click' <i>(Random Integer)</i></li>
#     <li>'Percentage Click' <i>(click / view * 100)</i></li>
#     <li>'Sold' <i>(Random Integer)</i></li>
#     <li>'Total Sold' <i>(Random Integer)</i></li>
#     <li>'% Sold' <i>(Total Sold / Klik)</i></li>
#     <li>'average' <i>(Outcome / Click)</i></li>
# </ol>
